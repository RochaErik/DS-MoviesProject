# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('movies_complete.csv', parse_dates=['release_date'])

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %%
df.describe()
# Out:
#              id  budget_musd  revenue_musd  vote_count  vote_average  \
# count  44691.00      8854.00       7385.00    44691.00      42077.00
# mean  107186.24        21.67         68.97      111.65          6.00
# std   111806.36        34.36        146.61      495.32          1.28
# min        2.00         0.00          0.00        0.00          0.00
# 25%    26033.50         2.00          2.41        3.00          5.30
# 50%    59110.00         8.20         16.87       10.00          6.10
# 75%   154251.00        25.00         67.64       35.00          6.80
# max   469172.00       380.00       2787.97    14075.00         10.00
#
#        popularity  runtime  cast_size  crew_size
# count    44691.00 43179.00   44691.00   44691.00
# mean         2.96    97.57      12.48      10.31
# std          6.04    34.65      12.12      15.89
# min          0.00     1.00       0.00       0.00
# 25%          0.40    86.00       6.00       2.00
# ...

# %%
df.hist(figsize=(20,12), bins=100)
plt.show()

# %%
df.budget_musd.value_counts(dropna=False).head(20)
# Out:
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
df.revenue_musd.value_counts(dropna=False).head(20)
# Out:
# NaN      37306
# 12.00       20
# 10.00       19
# 11.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 1.00        10
# 20.00       10
# 0.00         9
# 1.50         9
# 4.00         9
# 30.00        8
# 4.10         8
# Name: revenue_musd, dtype: int64

# %%
df.vote_average.value_counts(dropna=False).head(20)
# Out:
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
# 6.30    1583
# 5.50    1369
# 5.80    1358
# 6.40    1343
# 6.70    1328
# 6.80    1316
# 6.10    1274
# 6.60    1250
# 6.20    1240
# 5.90    1189
# 5.30    1068
# 5.70    1039
# 6.90    1029
# 5.60     994
# 7.30     987
# Name: vote_average, dtype: int64

# %%
df.vote_count.value_counts(dropna=False).head(20)
# Out:
# 1.00     3186
# 2.00     3056
# 3.00     2729
# 0.00     2614
# 4.00     2442
# 5.00     2066
# 6.00     1724
# 7.00     1553
# 8.00     1333
# 9.00     1179
# 10.00    1156
# 11.00     933
# 12.00     850
# 13.00     725
# 14.00     697
# 15.00     671
# 16.00     599
# 17.00     551
# 18.00     496
# 20.00     459
# Name: vote_count, dtype: int64

# %%
df.describe(include='object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %% [markdown]
# As we can see, we have duplicates (44691 titles with 41605 unique)

# %%
df[df['title']=='Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %%
from IPython.display import HTML

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df_best = df[['poster_path', 'title', 'budget_musd', 'revenue_musd', 'vote_count', 'vote_average', 'popularity']].copy()

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best['profit_musd'] = df.revenue_musd.sub(df.budget_musd)
df_best['return'] = df.revenue_musd.div(df.budget_musd)

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best.columns = ['', 'Title', 'Budget', 'Revenue', 'Votes', 'Average Rating', 'Popularity', 'Profit', 'ROI']
df_best
# Out:
#                                                           \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              Title  Budget  Revenue   Votes  Average Rating  \
# 0                        Toy Story   30.00   373.55 5415.00            7.70
# 1                          Jumanji   65.00   262.80 2413.00            6.90
# ...

# %%
df_best.set_index('Title', inplace=True)

# %%
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
df_best.sort_values(by='Average Rating', ascending=False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# ...

# %% [markdown]
# We have movies with high average rating but with a very few number of votes

# %%
df_best.sort_values(by='ROI', ascending=False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %% [markdown]
# As we see, the dataset contains movies with high ROI values but without any budget value. (ROI = revenue/budget)

# %%
df_best.loc[df_best.Budget >= 5].sort_values(by='ROI', ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# ...

# %%
df_best.Budget.fillna(0, inplace=True)
df_best.Votes.fillna(0, inplace=True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Budget          44691 non-null  float64
#  2   Revenue         7385 non-null   float64
#  3   Votes           44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   Profit          5371 non-null   float64
#  7   ROI             5371 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 3.1+ MB

# %%
def best_worst(n, by, ascending=False, min_budget=0, min_votes=0):
    df2 = df_best.loc[(df_best.Budget >= min_budget) & (df_best.Votes >= min_votes), 
    ['',by]].sort_values(by=by, ascending=ascending).head(n).copy()

    return HTML(df2.to_html(escape=False))

# %% [markdown]
# **Top 5 movies in revenue**

# %%
best_worst(5, 'Revenue')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# **Top 5 movies in budget**

# %%
best_worst(5, 'Budget')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# **Worst 5 movies by profit**

# %%
best_worst(5, 'Profit', True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Lone Ranger</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//b2je2ZybNIzAOL1K1WPbbT6zt2M.jpg' style='height:100px;'></td>
#       <td>-165.71</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>-119.18</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lOKqLd0ud1wdwaPK5h6bGNZIVLT.jpg' style='height:100px;'></td>
#       <td>-111.01</td>
#     </tr>
#     <tr>
#       <th>Valerian and the City of a Thousand Planets</th>
# ...

# %% [markdown]
# **Top 5 movies by average rating**

# %%
best_worst(5, 'Average Rating', min_votes=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Planet Earth II</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gTvArgUjEUDxYMqJHSwVlrn1Cjk.jpg' style='height:100px;'></td>
#       <td>9.50</td>
#     </tr>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Cosmos</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mYrnDinyVDhWatHYSwADTTYqoMG.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>The Story of Film: An Odyssey</th>
# ...

# %% [markdown]
# **Worst 5 movies by average rating**

# %%
best_worst(5, 'Average Rating', ascending=True, min_votes=20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Saving Christmas</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6MLSD1OYGDWkCk05m7vA1xCrfKr.jpg' style='height:100px;'></td>
#       <td>1.70</td>
#     </tr>
#     <tr>
#       <th>Superbabies: Baby Geniuses 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7viULokoVzqrgVj0EljfXDzEKMk.jpg' style='height:100px;'></td>
#       <td>1.90</td>
#     </tr>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dcDR1ZhZvA7HQvxQ17hzFjeCNHx.jpg' style='height:100px;'></td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Birdemic: Shock and Terror</th>
# ...

# %% [markdown]
# **Finding Movies**

# %% [markdown]
# 1 - Drama or action movie with Tom Hanks (High rating)

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
mask_genres = df.genres.str.contains('Drama') | df.genres.str.contains('Action')
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 44686     True
# 44687     True
# 44688     True
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
mask_actor = df.cast.str.contains('Tom Hanks')
mask_actor
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_genres & mask_actor, ['title', 'vote_average']].sort_values(by='vote_average', ascending=False)
# Out:
#                                    title  vote_average
# 9047          From the Earth to the Moon          8.40
# 42499                   Band of Brothers          8.20
# 350                         Forrest Gump          8.20
# 3002                      The Green Mile          8.20
# 1897                 Saving Private Ryan          7.90
# 5804                 Catch Me If You Can          7.70
# 502                         Philadelphia          7.60
# 21565                   Captain Phillips          7.60
# 3864                           Cast Away          7.50
# 21987                   Saving Mr. Banks          7.30
# 5286                   Road to Perdition          7.30
# 147                            Apollo 13          7.30
# 32937                    Bridge of Spies          7.20
# 7765                        The Terminal          7.10
# 38885                              Sully          7.00
# 18044  Extremely Loud & Incredibly Close          6.90
# ...

# %%
tom = df.loc[mask_genres & mask_actor, ['title', 'poster_path', 'vote_average']].sort_values(by='vote_average', ascending=False)

# %%
HTML(tom.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9047</th>
#       <td>From the Earth to the Moon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//yECLq6UpcldfblPTd2OJmqMDOEC.jpg' style='height:100px;'></td>
#       <td>8.40</td>
#     </tr>
#     <tr>
#       <th>42499</th>
#       <td>Band of Brothers</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//yRXTVpDRBA3983C3HjoY0SO4dV6.jpg' style='height:100px;'></td>
#       <td>8.20</td>
#     </tr>
#     <tr>
#       <th>350</th>
#       <td>Forrest Gump</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//saHP97rTPS5eLmrLQEcANmKrsFl.jpg' style='height:100px;'></td>
#       <td>8.20</td>
#     </tr>
#     <tr>
#       <th>3002</th>
#       <td>The Green Mile</td>
# ...

# %% [markdown]
# 2 - Movies with De Niro directed by Martin Scorcese

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
mask_director = df.director == 'Martin Scorsese'

# %%
mask_actor = df.cast.str.contains('Robert De Niro')

# %%
movie = df.loc[mask_director & mask_actor, ['title', 'poster_path', 'vote_average']].sort_values(by='vote_average', ascending=False).set_index('title')

# %%
HTML(movie.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>GoodFellas</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oErEczcVUmJm0EPdvWsvK4g4Lv3.jpg' style='height:100px;'></td>
#       <td>8.20</td>
#     </tr>
#     <tr>
#       <th>Taxi Driver</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ekstpH614fwDX8DUln1a2Opz0N8.jpg' style='height:100px;'></td>
#       <td>8.10</td>
#     </tr>
#     <tr>
#       <th>Casino</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//13jmXenVmAQGHlsiVOdrQaVnOzd.jpg' style='height:100px;'></td>
#       <td>7.80</td>
#     </tr>
#     <tr>
#       <th>Raging Bull</th>
# ...

# %% [markdown]
# 3 - Most successfull Pixar movie between 2001 - 2015 by Revenue

# %%
df.production_companies[0]
# Out:
# 'Pixar Animation Studios'

# %%
mask_prod_comp = df.production_companies.str.contains('Pixar').fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44686          NaT
# 44687   2011-11-17
# 44688   2003-08-01
# 44689   1917-10-21
# 44690   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %%
mask_time = df.release_date.between('2001-01-01', '2015-12-31')
mask_time
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687     True
# 44688     True
# 44689    False
# 44690    False
# Name: release_date, Length: 44691, dtype: bool

# %%
pixar = df.loc[mask_prod_comp & mask_time, ['title', 'poster_path', 'revenue_musd', 'release_date']].sort_values(by='revenue_musd', ascending=False).set_index('title')

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Finding Nemo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//n5eTY87wowab53RrcU2DqdK5MNB.jpg' style='height:100px;'></td>
#       <td>940.34</td>
#       <td>2003-05-30</td>
#     </tr>
#     <tr>
#       <th>Inside Out</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
# ...

# %% [markdown]
# **Most common words in movies**

# %%
from wordcloud import WordCloud

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
title = df.title.dropna()
tagline = df.tagline.dropna()
overview = df.overview.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
title_corpus = ' '.join(title)
tagline_corpus = ' '.join(tagline)
overview_corpus = ' '.join(overview)

# %%
title_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(title_corpus)

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
tagline_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(tagline_corpus)
plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
overview_wordcloud = WordCloud(background_color='white', height=2000, width=4000, max_words=200).generate(overview_corpus)
plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Are franchises more successfull?**

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df['Franchise'] = df.belongs_to_collection.notna()

# %%
df.Franchise
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: Franchise, Length: 44691, dtype: bool

# %%
df.Franchise.value_counts()
# Out:
# False    40228
# True      4463
# Name: Franchise, dtype: int64

# %% [markdown]
# Franchise vs Stand-alone group by **Average Revenue**

# %%
plt.figure(figsize=(5,5))
sns.displot(df['revenue_musd'], bins=50, kde=True)

# %%
df.groupby('Franchise').revenue_musd.median()
# Out:
# Franchise
# False   12.00
# True    67.20
# Name: revenue_musd, dtype: float64

# %%
# df.groupby('Franchise').revenue_musd.mean()

# %% [markdown]
# Franchise vs Stand-alone group by **ROI**

# %%
df['ROI'] = df.revenue_musd.div(df.budget_musd)

# %%
df['ROI']
# Out:
# 0       12.45
# 1        4.04
# 2         NaN
# 3        5.09
# 4         NaN
#          ...
# 44686     NaN
# 44687     NaN
# 44688     NaN
# 44689     NaN
# 44690     NaN
# Name: ROI, Length: 44691, dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.displot(df['ROI'], bins=200, kde=True)

# %%
df.groupby('Franchise').ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# Franchise vs Stand-alone group by **Average Budget**

# %%
plt.figure(figsize=(5,5))
sns.histplot(df['budget_musd'], bins=100, kde=True)
# Out:
# <AxesSubplot:xlabel='budget_musd', ylabel='Count'>

# %%
df.groupby('Franchise').budget_musd.median()
# Out:
# Franchise
# False    7.04
# True    16.00
# Name: budget_musd, dtype: float64

# %%
# df.groupby('Franchise').budget_musd.mean()

# %% [markdown]
# Franchise vs Stand-alone group by **Average Popularity**

# %%
plt.figure(figsize=(5,5))
plt.ylim(0, 40000)
sns.histplot(df['popularity'], bins=200, kde=True)
# Out:
# <AxesSubplot:xlabel='popularity', ylabel='Count'>

# %%
df.groupby('Franchise').popularity.median()
# Out:
# Franchise
# False   1.04
# True    3.71
# Name: popularity, dtype: float64

# %%
# df.groupby('Franchise').popularity.mean()

# %% [markdown]
# Franchise vs Stand-alone group by **Average Rating**

# %%
plt.figure(figsize=(5,5))
sns.histplot(df['vote_average'], bins=50, kde=True)
# Out:
# <AxesSubplot:xlabel='vote_average', ylabel='Count'>

# %%
df.groupby('Franchise').vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %% [markdown]
# In short...

# %%
df.groupby('Franchise').agg({'budget_musd': 'median', 'revenue_musd': 'median', 'vote_average': 'mean', 'popularity': 'median', 'ROI': 'median', 'vote_count': 'median'})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False             7.04         12.00          6.01        1.04 1.62
# True             16.00         67.20          5.96        3.71 3.71
#
#            vote_count
# Franchise
# False            9.00
# True            36.00

# %% [markdown]
# Apparently, franchises are more successful than stand-alone movies

# %% [markdown]
# **Most successful franchises**

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df.belongs_to_collection.value_counts()
# Out:
# The Bowery Boys                  29
# Totò Collection                  27
# Zatôichi: The Blind Swordsman    26
# James Bond Collection            26
# The Carry On Collection          25
#                                  ..
# Salt and Pepper Collection        1
# Deadpool Collection               1
# Ant-Man Collection                1
# Elvira Collection                 1
# Red Lotus Collection              1
# Name: belongs_to_collection, Length: 1691, dtype: int64

# %%
franchises = df.groupby('belongs_to_collection').agg({
                                                      'title': 'count', 
                                                      'budget_musd': ['median', 'sum'],
                                                      'revenue_musd': ['median', 'sum'], 
                                                      'vote_average': 'mean', 
                                                      'popularity': 'median',
                                                      'ROI': 'median',
                                                      'vote_count': 'median'
                                                      })

# %%
franchises
# Out:
#                                      title budget_musd        revenue_musd  \
#                                      count      median    sum       median
# belongs_to_collection
# ... Has Fallen Collection                2       65.00 130.00       183.39
# 00 Schneider Filmreihe                   1         NaN   0.00          NaN
# 08/15 Collection                         1         NaN   0.00          NaN
# 100 Girls Collection                     2         NaN   0.00          NaN
# 101 Dalmatians (Animated) Collection     2        4.00   4.00       215.88
# ...                                    ...         ...    ...          ...
# Сказки Чуковского                        1         NaN   0.00          NaN
# Чебурашка и крокодил Гена                1         NaN   0.00          NaN
# Что Творят мужчины! (Коллекция)          2        2.00   2.00          NaN
# 男はつらいよ シリーズ                              3         NaN   0.00          NaN
# ...

# %%
franchises.nlargest(20, ('title', 'count'))
# Out:
#                                        title budget_musd         revenue_musd  \
#                                        count      median     sum       median
# belongs_to_collection
# The Bowery Boys                           29         NaN    0.00          NaN
# Totò Collection                           27         NaN    0.00          NaN
# James Bond Collection                     26       29.00 1539.65       173.61
# Zatôichi: The Blind Swordsman             26         NaN    0.00          NaN
# The Carry On Collection                   25         NaN    0.00          NaN
# Charlie Chan (Sidney Toler) Collection    21         NaN    0.00          NaN
# Pokémon Collection                        20       30.00  250.72        50.00
# Godzilla (Showa) Collection               16        0.65    2.81          NaN
# Charlie Chan (Warner Oland) Collection    15         NaN    0.00          NaN
# Dragon Ball Z (Movie) Collection          15        5.00    5.00        56.06
# ...

# %%
franchises.nlargest(20, ('revenue_musd', 'median'))
# Out:
#                                     title budget_musd         revenue_musd  \
#                                     count      median     sum       median
# belongs_to_collection
# Avatar Collection                       1      237.00  237.00      2787.97
# The Avengers Collection                 2      250.00  500.00      1462.48
# Frozen Collection                       2      150.00  150.00      1274.22
# The Dark Knight Collection              3      185.00  585.00      1004.56
# Despicable Me Collection                6       75.00  299.00       995.41
# Finding Nemo Collection                 2      147.00  294.00       984.45
# Pirates of the Caribbean Collection     5      230.00 1250.00       961.00
# The Hobbit Collection                   3      250.00  750.00       958.40
# Harry Potter Collection                 8      140.00 1280.00       936.09
# The Lord of the Rings Collection        3       93.00  266.00       926.29
# ...

# %%
franchises.nlargest(20, ('budget_musd', 'median'))
# Out:
#                                         title budget_musd          \
#                                         count      median     sum
# belongs_to_collection
# Tangled Collection                          2      260.00  260.00
# The Avengers Collection                     2      250.00  500.00
# The Hobbit Collection                       3      250.00  750.00
# Man of Steel Collection                     2      237.50  475.00
# Avatar Collection                           1      237.00  237.00
# Pirates of the Caribbean Collection         5      230.00 1250.00
# The Amazing Spider-Man Collection           2      207.50  415.00
# Iron Man Collection                         3      200.00  540.00
# Spider-Man Collection                       3      200.00  597.00
# World War Z Collection                      1      200.00  200.00
# Transformers Collection                     5      195.00  965.00
# Alice in Wonderland Collection              2      185.00  370.00
# ...

# %%
#choose vote_average but only return franchises with 1000 votes or more

franchises[franchises[('vote_count', 'median')] > 1000].nlargest(20, ('vote_average', 'mean'))
# Out:
#                                     title budget_musd         revenue_musd  \
#                                     count      median     sum       median
# belongs_to_collection
# The Lord of the Rings Collection        3       93.00  266.00       926.29
# The Godfather Collection                3       13.00   73.00       136.77
# Blade Runner Collection                 1       28.00   28.00        33.14
# The Dark Knight Collection              3      185.00  585.00      1004.56
# Guardians of the Galaxy Collection      2      185.00  370.00       818.37
# Kill Bill Collection                    2       30.00   60.00       166.55
# Kingsman Collection                     1       81.00   81.00       414.35
# How to Train Your Dragon Collection     2      155.00  310.00       552.00
# Harry Potter Collection                 8      140.00 1280.00       936.09
# Toy Story Collection                    3       90.00  320.00       497.37
# ...

# %% [markdown]
# So, according to vote_average The Lord of The Ring collection is the most successful franchise

# %% [markdown]
# **The most successful director**

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
df.director.value_counts().head(20)
# Out:
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Georges Méliès        49
# Woody Allen           49
# Jean-Luc Godard       46
# Sidney Lumet          46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Ingmar Bergman        39
# Martin Scorsese       39
# Fritz Lang            38
# John Huston           38
# George Cukor          38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: director, dtype: int64

# %%
plt.figure(figsize=(10,5))
df.director.value_counts().head(20).plot(kind='bar', fontsize=15)
plt.title('Most Active Directors', fontsize=15)
plt.ylabel('Numbers of movies', fontsize=15)
plt.show()

# %%
df.groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize=(10,5))
df.groupby('director').revenue_musd.sum().nlargest(20).plot(kind='bar', fontsize=15)
plt.title('Directors', fontsize=15)
plt.ylabel('Revenue', fontsize=15)
plt.show()

# %%
directors = df.groupby('director').agg({'title': 'count', 'vote_average': 'mean', 'vote_count': 'sum'})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, 'vote_average')
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# ...

# %% [markdown]
# Miyazaki appears to be the most successful director by vote_average

# %%
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains('Adventure')].groupby('director').revenue_musd.sum().nlargest(20)
# Out:
# director
# Peter Jackson      6402.07
# Steven Spielberg   6080.33
# Michael Bay        5691.25
# David Yates        5334.56
# J.J. Abrams        3319.12
# George Lucas       3199.11
# Gore Verbinski     3016.69
# Roland Emmerich    2983.14
# Joss Whedon        2963.83
# James Cameron      2877.97
# Andrew Adamson     2572.71
# Carlos Saldanha    2532.45
# Chris Columbus     2473.02
# Ridley Scott       2349.37
# Tim Burton         2323.02
# Francis Lawrence   2252.95
# Jon Favreau        2239.98
# Kyle Balda         2176.79
# Sam Raimi          2166.51
# Zack Snyder        2098.79
# Name: revenue_musd, dtype: float64

# %% [markdown]
# **Most successful actors**

# %%
df.cast
# Out:
# 0        Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 3        Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                ...
# 44686              Leila Hatami|Kourosh Tahami|Elham Korda
# 44687    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 44688    Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 44689    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 44690                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
#each movie has his own unique id so we can set the index = id

df.set_index('id', inplace=True)

# %%
df.cast
# Out:
# id
# 862       Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 8844      Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 15602     Walter Matthau|Jack Lemmon|Ann-Margret|Sophia ...
# 31357     Whitney Houston|Angela Bassett|Loretta Devine|...
# 11862     Steve Martin|Diane Keaton|Martin Short|Kimberl...
#                                 ...
# 439050              Leila Hatami|Kourosh Tahami|Elham Korda
# 111109    Angel Aquino|Perry Dizon|Hazel Orencio|Joel To...
# 67758     Erika Eleniak|Adam Baldwin|Julie du Page|James...
# 227506    Iwan Mosschuchin|Nathalie Lissenko|Pavel Pavlo...
# 461257                                                  NaN
# Name: cast, Length: 44691, dtype: object

# %%
act = df.cast.str.split('|', expand=True)
act
# Out:
#                      0                  1               2    \
# id
# 862            Tom Hanks          Tim Allen     Don Rickles
# 8844      Robin Williams      Jonathan Hyde   Kirsten Dunst
# 15602     Walter Matthau        Jack Lemmon     Ann-Margret
# 31357    Whitney Houston     Angela Bassett  Loretta Devine
# 11862       Steve Martin       Diane Keaton    Martin Short
# ...                  ...                ...             ...
# 439050      Leila Hatami     Kourosh Tahami     Elham Korda
# 111109      Angel Aquino        Perry Dizon   Hazel Orencio
# 67758      Erika Eleniak       Adam Baldwin   Julie du Page
# 227506  Iwan Mosschuchin  Nathalie Lissenko    Pavel Pavlov
# 461257               NaN                NaN             NaN
#
#                               3               4                  5    \
# id
# 862                    Jim Varney   Wallace Shawn  John Ratzenberger
# 8844               Bradley Pierce     Bonnie Hunt      Bebe Neuwirth
# ...

# %%
act.stack()
# Out:
# id
# 862     0            Tom Hanks
#         1            Tim Allen
#         2          Don Rickles
#         3           Jim Varney
#         4        Wallace Shawn
#                    ...
# 227506  0     Iwan Mosschuchin
#         1    Nathalie Lissenko
#         2         Pavel Pavlov
#         3    Aleksandr Chabrov
#         4          Vera Orlova
# Length: 557703, dtype: object

# %%
#convert each columns to index (stack()) then remove the second column (reset_index(level=1, drop=True)) and finally converts all to a dataframe
act = act.stack().reset_index(level=1, drop=True).to_frame()
act
# Out:
#                         0
# id
# 862             Tom Hanks
# 862             Tim Allen
# 862           Don Rickles
# 862            Jim Varney
# 862         Wallace Shawn
# ...                   ...
# 227506   Iwan Mosschuchin
# 227506  Nathalie Lissenko
# 227506       Pavel Pavlov
# 227506  Aleksandr Chabrov
# 227506        Vera Orlova
#
# [557703 rows x 1 columns]

# %%
act.columns = ['Actors']

# %%
right = df[['title', 'revenue_musd', 'vote_average', 'popularity']]
right
# Out:
#                               title  revenue_musd  vote_average  popularity
# id
# 862                       Toy Story        373.55          7.70       21.95
# 8844                        Jumanji        262.80          6.90       17.02
# 15602              Grumpier Old Men           NaN          6.50       11.71
# 31357             Waiting to Exhale         81.45          6.10        3.86
# 11862   Father of the Bride Part II         76.58          5.70        8.39
# ...                             ...           ...           ...         ...
# 439050                       Subdue           NaN          4.00        0.07
# 111109          Century of Birthing           NaN          9.00        0.18
# 67758                      Betrayal           NaN          3.80        0.90
# 227506             Satan Triumphant           NaN           NaN        0.00
# 461257                     Queerama           NaN           NaN        0.16
#
# [44691 rows x 4 columns]

# %%
#merging on the index of both tables
act = act.merge(right, how='left', left_index=True, right_index=True)
act.head(20)
# Out:
#                Actors                title  revenue_musd  vote_average  \
# id
# 2         Turo Pajala                Ariel           NaN          7.10
# 2    Susanna Haavisto                Ariel           NaN          7.10
# 2     Matti Pellonpää                Ariel           NaN          7.10
# 2        Eetu Hilkamo                Ariel           NaN          7.10
# 3     Matti Pellonpää  Shadows in Paradise           NaN          7.10
# 3        Kati Outinen  Shadows in Paradise           NaN          7.10
# 3    Sakari Kuosmanen  Shadows in Paradise           NaN          7.10
# 3        Esko Nikkari  Shadows in Paradise           NaN          7.10
# 3        Kylli Köngäs  Shadows in Paradise           NaN          7.10
# 3         Pekka Laiho  Shadows in Paradise           NaN          7.10
# 3    Jukka-Pekka Palo  Shadows in Paradise           NaN          7.10
# 5            Tim Roth           Four Rooms          4.30          6.50
# ...

# %%
act.Actors.nunique()
# Out:
# 201501

# %%
act.Actors.unique()
# Out:
# array(['Turo Pajala', 'Susanna Haavisto', 'Matti Pellonpää', ...,
#        'Armanda Bacelar', 'Rafael de Sousa', 'José Antônio Gomes'],
#       dtype=object)

# %%
act.Actors.value_counts().head(20)
# Out:
# Bess Flowers          240
# Christopher Lee       148
# John Wayne            125
# Samuel L. Jackson     122
# Michael Caine         110
# Gérard Depardieu      109
# John Carradine        109
# Jackie Chan           108
# Donald Sutherland     108
# Frank Welker          107
# Robert De Niro        104
# Danny Trejo           101
# Steve Buscemi         101
# Irving Bacon           98
# John Goodman           97
# Christopher Walken     96
# Danny Glover           95
# John Hurt              93
# Susan Sarandon         92
# Dennis Hopper          92
# Name: Actors, dtype: int64

# %%
plt.figure(figsize=(10,5))
act.Actors.value_counts().head(20).plot(kind='bar', fontsize=15)
plt.title('Actors', fontsize=15)
plt.ylabel('Number of movies', fontsize=15)
plt.show()

# %%
actors_data = act.groupby('Actors').agg(Total_revenue = ('revenue_musd', 'sum'),
                          Median_revenue = ('revenue_musd', 'median'),
                          Mean_rating = ('vote_average', 'mean'),
                          Median_pop = ('popularity', 'median'),
                          Total_movies = ('Actors', 'count'))

# %%
actors_data.nlargest(20, 'Total_movies')
# Out:
#                     Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Actors
# Bess Flowers               368.91            7.20         6.18        0.87
# Christopher Lee           9417.05           97.57         5.91        2.08
# John Wayne                 236.09            7.80         5.71        1.58
# Samuel L. Jackson        17109.62           75.16         6.27        7.86
# Michael Caine             8053.40           51.32         6.27        5.11
# Gérard Depardieu          1247.61           31.06         6.05        2.48
# John Carradine             255.84            8.09         5.55        0.93
# Donald Sutherland         5390.77           45.30         6.23        4.25
# Jackie Chan               4699.19           72.18         6.28        5.39
# Frank Welker             13044.15          125.13         6.31        6.95
# Robert De Niro            5877.09           48.18         6.43        8.19
# ...

# %%
actors_data.nlargest(20, 'Total_revenue')
# Out:
#                    Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Actors
# Stan Lee                19414.96          648.34         6.51       14.17
# Samuel L. Jackson       17109.62           75.16         6.27        7.86
# Warwick Davis           13256.03          833.25         6.29       10.30
# Frank Welker            13044.15          125.13         6.31        6.95
# John Ratzenberger       12596.13          479.68         6.48       10.81
# Jess Harnell            12234.61          646.69         6.44        9.37
# Hugo Weaving            11027.58          377.45         6.47        7.09
# Ian McKellen            11015.59          407.71         6.35        4.48
# Johnny Depp             10653.76           98.19         6.44        9.73
# Alan Rickman            10612.63          133.59         6.72       10.04
# Gary Oldman             10534.77          120.55         6.51        9.92
# Alan Tudyk              10276.76          210.68         6.50        8.83
# ...

# %%
plt.figure(figsize=(10,5))
#actors_data.Total_revenue.nlargest(10).plot(kind='bar', fontsize=15)
actors_data['Total_revenue'].sort_values(ascending=False).head(10).plot(kind='bar', fontsize=15)
plt.title('Actors', fontsize=15)
plt.ylabel('Revenue', fontsize=15)
plt.show()

# %%
#All actors from the movie Avatar
actors_data.Median_revenue.nlargest(10)
# Out:
# Actors
# April Marie Thomas   2787.97
# Ashley Jeffery       2787.97
# Austin Wilson        2787.97
# Brandon Jelkes       2787.97
# Bravita A. Threatt   2787.97
# Carvon Futrell       2787.97
# Chris Mala           2787.97
# Christa Oliver       2787.97
# Christopher Nolen    2787.97
# Colin Bleasdale      2787.97
# Name: Median_revenue, dtype: float64

# %%
#Based on this data, we can't know who os the main actor of the movie
act[act.Actors == 'Austin Wilson']
# Out:
#               Actors   title  revenue_musd  vote_average  popularity
# id
# 19995  Austin Wilson  Avatar       2787.97          7.20      185.07

# %%
actors_data[actors_data.Total_movies >= 10].nlargest(10, 'Median_revenue')
# Out:
#                   Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Actors
# Gloria Stuart           1845.03         1845.03         6.37        1.60
# Zoë Wanamaker            976.48          976.48         6.33        2.07
# Keith Richards          2967.71          961.00         6.46        0.77
# Ellen DeGeneres         2263.36          940.34         5.80        5.41
# Natalia Tena            4305.78          936.09         6.51        7.28
# Matthew Lewis           7915.31          933.96         7.37       24.90
# James Cameron           1862.08          931.04         7.06        1.83
# Dominic Monaghan        3289.61          898.83         6.05        3.78
# Mark Williams           6872.09          895.92         6.76       10.08
# Adrian Rawlins          6804.07          886.30         6.64        8.56
#
#                   Total_movies
# Actors
# Gloria Stuart               18
# Zoë Wanamaker               10
# Keith Richards              23
# ...

# %%
actors_data[actors_data.Total_movies >= 10].nlargest(10, 'Median_pop')
# Out:
#                  Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Actors
# Terry Notary           6947.21          524.76         6.47       29.43
# Matthew Lewis          7915.31          933.96         7.37       24.90
# Mark Smith             2195.52          173.57         6.55       24.64
# Joseph Oliveira        3543.44          261.70         7.64       19.12
# Emma Watson            9639.20          576.22         6.77       19.08
# Sam Claflin            4107.08          186.27         6.39       17.26
# Bob Peterson           6058.96          739.33         7.17       16.97
# Mickie McGowan         6091.71          521.31         7.42       16.97
# Jan Rabson             6415.12          857.61         6.85       16.53
# Paula Malcomson        3286.84          653.43         6.60       16.43
#
#                  Total_movies
# Actors
# Terry Notary               11
# Matthew Lewis              11
# Mark Smith                 11
# Joseph Oliveira            10
# ...

# %% [markdown]
# **Most successful genres**

# %%
df.genres
# Out:
# id
# 862        Animation|Comedy|Family
# 8844      Adventure|Fantasy|Family
# 15602               Romance|Comedy
# 31357         Comedy|Drama|Romance
# 11862                       Comedy
#                     ...
# 439050                Drama|Family
# 111109                       Drama
# 67758        Action|Drama|Thriller
# 227506                         nan
# 461257                         nan
# Name: genres, Length: 44691, dtype: object

# %%
genres = df.genres.str.split('|', expand=True)
genres
# Out:
#                 0        1         2     3     4     5     6     7
# id
# 862     Animation   Comedy    Family  None  None  None  None  None
# 8844    Adventure  Fantasy    Family  None  None  None  None  None
# 15602     Romance   Comedy      None  None  None  None  None  None
# 31357      Comedy    Drama   Romance  None  None  None  None  None
# 11862      Comedy     None      None  None  None  None  None  None
# ...           ...      ...       ...   ...   ...   ...   ...   ...
# 439050      Drama   Family      None  None  None  None  None  None
# 111109      Drama     None      None  None  None  None  None  None
# 67758      Action    Drama  Thriller  None  None  None  None  None
# 227506        nan     None      None  None  None  None  None  None
# 461257        nan     None      None  None  None  None  None  None
#
# [44691 rows x 8 columns]

# %%
genres.stack()
# Out:
# id
# 862     0    Animation
#         1       Comedy
#         2       Family
# 8844    0    Adventure
#         1      Fantasy
#                ...
# 67758   0       Action
#         1        Drama
#         2     Thriller
# 227506  0          nan
# 461257  0          nan
# Length: 92330, dtype: object

# %%
genres = genres.stack().reset_index(level=1, drop=True).to_frame()
genres
# Out:
#                 0
# id
# 862     Animation
# 862        Comedy
# 862        Family
# 8844    Adventure
# 8844      Fantasy
# ...           ...
# 67758      Action
# 67758       Drama
# 67758    Thriller
# 227506        nan
# 461257        nan
#
# [92330 rows x 1 columns]

# %%
genres.columns = ['Genres']

# %%
genres
# Out:
#            Genres
# id
# 862     Animation
# 862        Comedy
# 862        Family
# 8844    Adventure
# 8844      Fantasy
# ...           ...
# 67758      Action
# 67758       Drama
# 67758    Thriller
# 227506        nan
# 461257        nan
#
# [92330 rows x 1 columns]

# %%
right = df[['revenue_musd', 'vote_average', 'popularity', 'release_date']]
right
# Out:
#         revenue_musd  vote_average  popularity release_date
# id
# 862           373.55          7.70       21.95   1995-10-30
# 8844          262.80          6.90       17.02   1995-12-15
# 15602            NaN          6.50       11.71   1995-12-22
# 31357          81.45          6.10        3.86   1995-12-22
# 11862          76.58          5.70        8.39   1995-02-10
# ...              ...           ...         ...          ...
# 439050           NaN          4.00        0.07          NaT
# 111109           NaN          9.00        0.18   2011-11-17
# 67758            NaN          3.80        0.90   2003-08-01
# 227506           NaN           NaN        0.00   1917-10-21
# 461257           NaN           NaN        0.16   2017-06-09
#
# [44691 rows x 4 columns]

# %%
genres = genres.merge(right, how='left', left_index=True, right_index=True)
genres.head(20)
# Out:
#              Genres  revenue_musd  vote_average  popularity release_date
# id
# 2             Drama           NaN          7.10        3.86   1988-10-21
# 2             Crime           NaN          7.10        3.86   1988-10-21
# 3             Drama           NaN          7.10        2.29   1986-10-16
# 3            Comedy           NaN          7.10        2.29   1986-10-16
# 5             Crime          4.30          6.50        9.03   1995-12-09
# 5            Comedy          4.30          6.50        9.03   1995-12-09
# 6            Action         12.14          6.40        5.54   1993-10-15
# 6          Thriller         12.14          6.40        5.54   1993-10-15
# 6             Crime         12.14          6.40        5.54   1993-10-15
# 11        Adventure        775.40          8.10       42.15   1977-05-25
# 11           Action        775.40          8.10       42.15   1977-05-25
# 11  Science Fiction        775.40          8.10       42.15   1977-05-25
# ...

# %%
genres.Genres.nunique()
# Out:
# 21

# %%
genres.Genres.unique()
# Out:
# array(['Drama', 'Crime', 'Comedy', 'Action', 'Thriller', 'Adventure',
#        'Science Fiction', 'Animation', 'Family', 'Romance', 'Mystery',
#        'Music', 'Horror', 'Fantasy', 'Documentary', 'War', 'Western',
#        'History', 'Foreign', 'TV Movie', 'nan'], dtype=object)

# %%
genres.Genres.value_counts().head(20)
# Out:
# Drama              20054
# Comedy             13067
# Thriller            7565
# Romance             6662
# Action              6542
# Horror              4634
# Crime               4282
# Documentary         3867
# Adventure           3468
# Science Fiction     3013
# Family              2740
# Mystery             2453
# Fantasy             2290
# nan                 2105
# Animation           1911
# Music               1587
# Foreign             1586
# History             1391
# War                 1317
# Western             1038
# Name: Genres, dtype: int64

# %%
genres = genres[genres['Genres'] != 'nan']

# %%
genres.Genres.value_counts().head(20)
# Out:
# Drama              20054
# Comedy             13067
# Thriller            7565
# Romance             6662
# Action              6542
# Horror              4634
# Crime               4282
# Documentary         3867
# Adventure           3468
# Science Fiction     3013
# Family              2740
# Mystery             2453
# Fantasy             2290
# Animation           1911
# Music               1587
# Foreign             1586
# History             1391
# War                 1317
# Western             1038
# TV Movie             758
# Name: Genres, dtype: int64

# %%
plt.figure(figsize=(10,5))
genres.Genres.value_counts().head(20).plot(kind='bar', fontsize=15)
plt.title('Genres', fontsize=15)
plt.ylabel('Number of movies', fontsize=15)
plt.show()

# %%
genres_data = genres.groupby('Genres').agg(Total_revenue = ('revenue_musd', 'sum'),
                          Median_revenue = ('revenue_musd', 'median'),
                          Mean_rating = ('vote_average', 'mean'),
                          Median_pop = ('popularity', 'median'),
                          Total_movies = ('Genres', 'count'))

# %%
genres_data.nlargest(30,'Median_revenue')
# Out:
#                  Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Genres
# Animation             67432.97           66.21         6.45        2.21
# Adventure            199978.67           63.27         5.88        2.98
# Family               107076.78           61.14         5.93        2.31
# Fantasy              103920.15           51.40         5.93        2.54
# TV Movie                 42.00           42.00         5.64        1.05
# Action               201388.05           34.79         5.75        2.22
# Science Fiction       97847.96           34.11         5.48        2.18
# Thriller             129724.55           21.86         5.74        2.36
# Crime                 63375.73           21.15         6.10        2.01
# War                   15910.46           20.97         6.29        1.35
# History               14902.20           20.17         6.41        1.64
# Mystery               34754.61           19.73         5.96        1.82
# ...

# %%
genres_data.nlargest(30,'Mean_rating')
# Out:
#                  Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Genres
# Documentary            1449.11            0.36         6.66        0.39
# Animation             67432.97           66.21         6.45        2.21
# History               14902.20           20.17         6.41        1.64
# Music                 13370.29           12.30         6.33        0.98
# War                   15910.46           20.97         6.29        1.35
# Drama                160754.36           11.24         6.17        1.34
# Crime                 63375.73           21.15         6.10        2.01
# Romance               73473.19           13.27         6.04        1.46
# Foreign                 291.54            0.62         5.97        0.60
# Comedy               166845.05           19.35         5.97        1.43
# Mystery               34754.61           19.73         5.96        1.82
# Family               107076.78           61.14         5.93        2.31
# ...

# %%
genres_data.nlargest(30,'Median_pop')
# Out:
#                  Total_revenue  Median_revenue  Mean_rating  Median_pop  \
# Genres
# Adventure            199978.67           63.27         5.88        2.98
# Fantasy              103920.15           51.40         5.93        2.54
# Thriller             129724.55           21.86         5.74        2.36
# Family               107076.78           61.14         5.93        2.31
# Action               201388.05           34.79         5.75        2.22
# Animation             67432.97           66.21         6.45        2.21
# Science Fiction       97847.96           34.11         5.48        2.18
# Crime                 63375.73           21.15         6.10        2.01
# Horror                30837.09           14.80         5.31        1.85
# Mystery               34754.61           19.73         5.96        1.82
# History               14902.20           20.17         6.41        1.64
# Romance               73473.19           13.27         6.04        1.46
# ...

# %% [markdown]
# **80s**

# %%
genres.loc[genres.release_date.between('1980-01-01','1990-01-01')].groupby('Genres').revenue_musd.sum().nlargest(20)
# Out:
# Genres
# Comedy            13517.07
# Action            11190.20
# Adventure         10678.15
# Drama             10178.39
# Thriller           6894.62
# Science Fiction    5795.52
# Romance            5764.46
# Crime              4464.45
# Family             4428.11
# Fantasy            4411.73
# Horror             2935.56
# War                1784.11
# Mystery            1203.36
# Music              1154.25
# Animation          1033.85
# History             715.13
# Western             143.25
# Documentary          19.07
# Foreign               8.83
# TV Movie              0.00
# Name: revenue_musd, dtype: float64

# %% [markdown]
# In the 80s the genres with the best revenue results are comedy, action and adventure

# %% [markdown]
# **90s**

# %%
genres.loc[genres.release_date.between('1990-01-01','2000-01-01')].groupby('Genres').revenue_musd.sum().nlargest(20)
# Out:
# Genres
# Drama             35110.63
# Comedy            29158.91
# Thriller          27929.24
# Action            26987.19
# Adventure         22289.78
# Romance           17114.47
# Crime             15080.36
# Family            13416.66
# Science Fiction   13207.04
# Fantasy           11080.89
# Mystery            9284.13
# Animation          6555.72
# Horror             4584.56
# History            2426.59
# War                2182.72
# Music              2121.93
# Western            1258.61
# Documentary         193.25
# Foreign              55.95
# TV Movie             42.00
# Name: revenue_musd, dtype: float64

# %% [markdown]
# In the 90s, the data shows that besides the revenue from comedy movies more than double, the leading genre is drama, followed by comedy, and finally thriller

# %% [markdown]
# **The most successful/active production companies**

# %%
df.production_companies
# Out:
# id
# 862                                 Pixar Animation Studios
# 8844      TriStar Pictures|Teitler Film|Interscope Commu...
# 15602                           Warner Bros.|Lancaster Gate
# 31357                Twentieth Century Fox Film Corporation
# 11862             Sandollar Productions|Touchstone Pictures
#                                 ...
# 439050                                                  NaN
# 111109                                          Sine Olivia
# 67758                               American World Pictures
# 227506                                            Yermoliev
# 461257                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
production_companies = df.production_companies.str.split('|', expand=True)
production_companies
# Out:
#                                             0                    1   \
# id
# 862                    Pixar Animation Studios                 None
# 8844                          TriStar Pictures         Teitler Film
# 15602                             Warner Bros.       Lancaster Gate
# 31357   Twentieth Century Fox Film Corporation                 None
# 11862                    Sandollar Productions  Touchstone Pictures
# ...                                        ...                  ...
# 439050                                     NaN                  NaN
# 111109                             Sine Olivia                 None
# 67758                  American World Pictures                 None
# 227506                               Yermoliev                 None
# 461257                                     NaN                  NaN
#
#                                2     3     4     5     6     7     8     9   \
# id
# ...

# %%
production_companies.stack()
# Out:
# id
# 862     0          Pixar Animation Studios
# 8844    0                 TriStar Pictures
#         1                     Teitler Film
#         2        Interscope Communications
# 15602   0                     Warner Bros.
#                          ...
# 30840   2      20th Century Fox Television
#         3    CanWest Global Communications
# 111109  0                      Sine Olivia
# 67758   0          American World Pictures
# 227506  0                        Yermoliev
# Length: 70029, dtype: object

# %%
production_companies = production_companies.stack().reset_index(level=1, drop=True).to_frame()
production_companies
# Out:
#                                     0
# id
# 862           Pixar Animation Studios
# 8844                 TriStar Pictures
# 8844                     Teitler Film
# 8844        Interscope Communications
# 15602                    Warner Bros.
# ...                               ...
# 30840     20th Century Fox Television
# 30840   CanWest Global Communications
# 111109                    Sine Olivia
# 67758         American World Pictures
# 227506                      Yermoliev
#
# [70029 rows x 1 columns]

# %%
production_companies.nunique()
# Out:
# 0    23422
# dtype: int64

# %%
production_companies.value_counts()
# Out:
# Warner Bros.                              1248
# Metro-Goldwyn-Mayer (MGM)                 1073
# Paramount Pictures                         996
# Twentieth Century Fox Film Corporation     834
# Universal Pictures                         827
#                                           ...
# Herald Pictures                              1
# Herald Ace                                   1
# Her Best Move LLC                            1
# Hepp Film                                    1
# 프로덕션M                                        1
# Length: 23422, dtype: int64

# %%
production_companies.columns = ['Production_companies']

# %%
right = df[['title', 'revenue_musd', 'vote_average', 'vote_count', 'popularity']]
right
# Out:
#                               title  revenue_musd  vote_average  vote_count  \
# id
# 862                       Toy Story        373.55          7.70     5415.00
# 8844                        Jumanji        262.80          6.90     2413.00
# 15602              Grumpier Old Men           NaN          6.50       92.00
# 31357             Waiting to Exhale         81.45          6.10       34.00
# 11862   Father of the Bride Part II         76.58          5.70      173.00
# ...                             ...           ...           ...         ...
# 439050                       Subdue           NaN          4.00        1.00
# 111109          Century of Birthing           NaN          9.00        3.00
# 67758                      Betrayal           NaN          3.80        6.00
# 227506             Satan Triumphant           NaN           NaN        0.00
# 461257                     Queerama           NaN           NaN        0.00
#
#         popularity
# id
# 862          21.95
# ...

# %%
production_companies = production_companies.merge(right, how='left', left_index=True, right_index=True)
production_companies.head(20)
# Out:
#                       Production_companies                title  revenue_musd  \
# id
# 2              Villealfa Filmproduction Oy                Ariel           NaN
# 2                  Finnish Film Foundation                Ariel           NaN
# 3              Villealfa Filmproduction Oy  Shadows in Paradise           NaN
# 5                            Miramax Films           Four Rooms          4.30
# 5                             A Band Apart           Four Rooms          4.30
# 6                       Universal Pictures       Judgment Night         12.14
# 6                      Largo Entertainment       Judgment Night         12.14
# 6               JVC Entertainment Networks       Judgment Night         12.14
# 11                               Lucasfilm            Star Wars        775.40
# 11  Twentieth Century Fox Film Corporation            Star Wars        775.40
# 12                 Pixar Animation Studios         Finding Nemo        940.34
# ...

# %%
production_companies.Production_companies.nunique()
# Out:
# 23422

# %%
production_companies_data = production_companies.groupby('Production_companies').agg(Total_revenue = ('revenue_musd', 'sum'),
                          Median_revenue = ('revenue_musd', 'median'),
                          Mean_rating = ('vote_average', 'mean'),
                          Total_votes = ('vote_count', 'sum'),
                          Median_pop = ('popularity', 'median'),
                          Total_movies = ('Production_companies', 'count'))

# %%
production_companies_data
# Out:
#                                  Total_revenue  Median_revenue  Mean_rating  \
# Production_companies
#  Movie Studios                            0.00             NaN         5.50
# "DIA" Productions GmbH & Co. KG          44.35           44.35         5.80
# # Andrea Sperling Productions             0.00             NaN         5.70
# # Lexyn Productions                       0.00             NaN         6.30
# 'A' Production Committee                  0.00             NaN          NaN
# ...                                        ...             ...          ...
# 영화사 집                                     0.00             NaN         7.00
# 이디오플랜                                     0.00             NaN         6.90
# 인벤트 디                                     0.00             NaN         6.90
# 타임스토리그룹                                   0.00             NaN         6.50
# 프로덕션M                                     0.00             NaN         6.20
#
# ...

# %%
production_companies_data.nlargest(20, 'Total_revenue')
# Out:
#                                         Total_revenue  Median_revenue  \
# Production_companies
# Warner Bros.                                 63525.19           55.00
# Universal Pictures                           55259.19           59.61
# Paramount Pictures                           48769.40           52.03
# Twentieth Century Fox Film Corporation       47687.75           60.21
# Walt Disney Pictures                         40837.27          151.17
# Columbia Pictures                            32279.74           75.89
# New Line Cinema                              22173.39           49.82
# Amblin Entertainment                         17343.72          171.53
# DreamWorks SKG                               15475.75          135.41
# Dune Entertainment                           15003.79          154.62
# Village Roadshow Pictures                    14904.70          100.09
# Relativity Media                             14603.15           85.28
# ...

# %% [markdown]
# The data shows that Warner Bros is the company with the best revenue ever

# %%
production_companies_data[production_companies_data.Total_movies > 3].nlargest(20, 'Median_revenue')
# Out:
#                                      Total_revenue  Median_revenue  \
# Production_companies
# Heyday films                               2701.83          799.57
# Illumination Entertainment                 5731.77          753.95
# Laura Ziskin Productions                   2619.71          752.22
# Heyday Films                               7920.01          716.39
# Total Entertainment                         712.17          712.17
# Hasbro Studios                             4472.03          709.71
# Imprint Entertainment                      1800.94          698.49
# Marvel Studios                            11699.64          623.93
# Syncopy                                    5359.86          591.36
# Pixar Animation Studios                   11188.53          561.33
# WingNut Films                              7111.00          550.00
# Marvel Entertainment                       4530.19          543.93
# Mark Gordon Productions                    1176.38          481.84
# ...

# %% [markdown]
# Heyday films has the best revenue amongst all companies

# %%
production_companies_data[(production_companies_data.Total_votes > 1000) & (production_companies_data.Total_movies > 3)].nlargest(20, 'Mean_rating')
# Out:
#                              Total_revenue  Median_revenue  Mean_rating  \
# Production_companies
# Hawk Films                          100.05           23.29         7.95
# Charles Chaplin Productions          13.52            2.50         7.76
# Nibariki                            245.55           68.00         7.57
# SODEC                                 3.56            1.78         7.57
# Xingu Films                          10.28            5.14         7.54
# Syncopy                            5359.86          591.36         7.47
# American Empirical Pictures         324.14           57.37         7.46
# Asymmetrical Productions             24.64            3.68         7.42
# Mitsubishi                          490.71          127.74         7.40
# Zazen Produções                      63.24           31.62         7.40
# Pulse Films                          40.42           40.42         7.38
# Rafran Cinematografica                5.32            5.32         7.38
# ...

# %% [markdown]
# Hawk Films is the company with the best rating results
